# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.mixed_precision import experimental as mixed_precision

policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_policy(policy)

inputs = keras.Input(shape=(784,), name='digits')
if tf.config.list_physical_devices('GPU'):
  print('The model will run with 4096 units on a GPU')
  num_units = 4096
else:
  # Use fewer units on CPUs so the model finishes in a reasonable amount of time
  print('The model will run with 64 units on a CPU')
  num_units = 64
dense1 = layers.Dense(num_units, activation='relu', name='dense_1')
x = dense1(inputs)
dense2 = layers.Dense(num_units, activation='relu', name='dense_2')
x = dense2(x)

x = layers.Dense(10, name='dense_logits')(x)
outputs = layers.Activation('softmax', dtype='float32', name='predictions')(x)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=keras.optimizers.RMSprop(),
              metrics=['accuracy'])

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
x_train = x_train.reshape(60000, 784).astype('float32') / 255
x_test = x_test.reshape(10000, 784).astype('float32') / 255

# 8192
history = model.fit(x_train, y_train,
                    batch_size=60000, 
                    epochs=50,
                    validation_split=0.2)
test_scores = model.evaluate(x_test, y_test, verbose=2)
print('Test loss:', test_scores[0])
print('Test accuracy:', test_scores[1])
# Out:
# The model will run with 4096 units on a GPU
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] - 1s 25us/sample - loss: 2.3163 - accuracy: 0.0946 - val_loss: 2.9184 - val_accuracy: 0.5432
# Epoch 2/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 3.0362 - accuracy: 0.5212 - val_loss: 17.5530 - val_accuracy: 0.2108
# Epoch 3/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 17.6374 - accuracy: 0.2180 - val_loss: 5.1214 - val_accuracy: 0.2936
# Epoch 4/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 5.1231 - accuracy: 0.2920 - val_loss: 1.6243 - val_accuracy: 0.5232
# Epoch 5/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 1.6404 - accuracy: 0.5183 - val_loss: 1.1034 - val_accuracy: 0.6955
# Epoch 6/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 1.1224 - accuracy: 0.6880 - val_loss: 0.6805 - val_accuracy: 0.8264
# Epoch 7/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.7113 - accuracy: 0.8123 - val_loss: 0.6412 - val_accuracy: 0.7977
# Epoch 8/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.6759 - accuracy: 0.7867 - val_loss: 1.0376 - val_accuracy: 0.6956
# Epoch 9/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 1.0961 - accuracy: 0.6788 - val_loss: 0.8050 - val_accuracy: 0.7161
# Epoch 10/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.8254 - accuracy: 0.7102 - val_loss: 0.6490 - val_accuracy: 0.7684
# Epoch 11/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.6895 - accuracy: 0.7547 - val_loss: 0.4850 - val_accuracy: 0.8492
# Epoch 12/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.5089 - accuracy: 0.8393 - val_loss: 0.3510 - val_accuracy: 0.9094
# Epoch 13/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.3756 - accuracy: 0.8989 - val_loss: 0.2996 - val_accuracy: 0.9177
# Epoch 14/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.3186 - accuracy: 0.9107 - val_loss: 0.2741 - val_accuracy: 0.9225
# Epoch 15/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.2924 - accuracy: 0.9156 - val_loss: 0.2848 - val_accuracy: 0.9136
# Epoch 16/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.2993 - accuracy: 0.9072 - val_loss: 0.3127 - val_accuracy: 0.9041
# Epoch 17/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.3280 - accuracy: 0.8969 - val_loss: 0.3991 - val_accuracy: 0.8712
# Epoch 18/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.4128 - accuracy: 0.8633 - val_loss: 0.3055 - val_accuracy: 0.9067
# Epoch 19/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.3201 - accuracy: 0.8986 - val_loss: 0.2721 - val_accuracy: 0.9129
# Epoch 20/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.2840 - accuracy: 0.9091 - val_loss: 0.2588 - val_accuracy: 0.9182
# Epoch 21/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.2706 - accuracy: 0.9129 - val_loss: 0.2806 - val_accuracy: 0.9070
# Epoch 22/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.2891 - accuracy: 0.9035 - val_loss: 0.2948 - val_accuracy: 0.9012
# Epoch 23/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.3066 - accuracy: 0.8942 - val_loss: 0.2649 - val_accuracy: 0.9133
# Epoch 24/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.2700 - accuracy: 0.9097 - val_loss: 0.2711 - val_accuracy: 0.9152
# Epoch 25/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.2742 - accuracy: 0.9150 - val_loss: 0.3358 - val_accuracy: 0.8967
# Epoch 26/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.3435 - accuracy: 0.8917 - val_loss: 0.2984 - val_accuracy: 0.9046
# Epoch 27/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.3007 - accuracy: 0.9037 - val_loss: 0.3077 - val_accuracy: 0.9097
# Epoch 28/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.3154 - accuracy: 0.9028 - val_loss: 0.2606 - val_accuracy: 0.9185
# Epoch 29/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.2601 - accuracy: 0.9169 - val_loss: 0.2357 - val_accuracy: 0.9305
# Epoch 30/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.2381 - accuracy: 0.9283 - val_loss: 0.3034 - val_accuracy: 0.9018
# Epoch 31/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.3019 - accuracy: 0.9043 - val_loss: 0.2427 - val_accuracy: 0.9270
# Epoch 32/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.2446 - accuracy: 0.9244 - val_loss: 0.1799 - val_accuracy: 0.9438
# Epoch 33/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.1778 - accuracy: 0.9448 - val_loss: 0.1699 - val_accuracy: 0.9510
# Epoch 34/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.1614 - accuracy: 0.9521 - val_loss: 0.1942 - val_accuracy: 0.9398
# Epoch 35/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.1851 - accuracy: 0.9406 - val_loss: 0.2187 - val_accuracy: 0.9329
# Epoch 36/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.2039 - accuracy: 0.9342 - val_loss: 0.2431 - val_accuracy: 0.9226
# Epoch 37/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.2320 - accuracy: 0.9248 - val_loss: 0.1888 - val_accuracy: 0.9434
# Epoch 38/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.1731 - accuracy: 0.9477 - val_loss: 0.1414 - val_accuracy: 0.9613
# Epoch 39/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.1316 - accuracy: 0.9630 - val_loss: 0.1494 - val_accuracy: 0.9551
# Epoch 40/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.1309 - accuracy: 0.9599 - val_loss: 0.1808 - val_accuracy: 0.9428
# Epoch 41/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.1754 - accuracy: 0.9434 - val_loss: 0.5446 - val_accuracy: 0.8665
# Epoch 42/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.5368 - accuracy: 0.8669 - val_loss: 0.5127 - val_accuracy: 0.8620
# Epoch 43/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.5246 - accuracy: 0.8625 - val_loss: 0.3349 - val_accuracy: 0.9070
# Epoch 44/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.3297 - accuracy: 0.9059 - val_loss: 0.2562 - val_accuracy: 0.9203
# Epoch 45/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.2364 - accuracy: 0.9260 - val_loss: 0.1651 - val_accuracy: 0.9565
# Epoch 46/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.1537 - accuracy: 0.9607 - val_loss: 0.1417 - val_accuracy: 0.9574
# Epoch 47/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.1237 - accuracy: 0.9637 - val_loss: 0.1574 - val_accuracy: 0.9538
# Epoch 48/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.1382 - accuracy: 0.9599 - val_loss: 0.1809 - val_accuracy: 0.9431
# Epoch 49/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.1660 - accuracy: 0.9472 - val_loss: 0.3550 - val_accuracy: 0.8998
# Epoch 50/50
# 48000/48000 [==============================] - 0s 6us/sample - loss: 0.3361 - accuracy: 0.9046 - val_loss: 0.1664 - val_accuracy: 0.9492
# 10000/10000 - 0s - loss: 0.1700 - accuracy: 0.9483
# Test loss: 0.16995484649688006
# Test accuracy: 0.9483
